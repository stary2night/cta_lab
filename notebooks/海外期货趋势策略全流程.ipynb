# %% [markdown]
# # 海外期货趋势策略全流程
#
# 基于 cta_lab 框架复现 cta/main_overseas.py 完整研究流程。
#
# **数据**：market_data/kline/overseas_daily_full/
# **策略**：OverseasTSMOM（三尺度 TSMOM + 等权合成）
# **分析**：危机 Alpha、多空不对称、板块归因（SECTOR_MAP_OVERSEAS）

# %% [markdown]
# ## 1. 数据加载

# %%
import sys
sys.path.insert(0, "..")

from pathlib import Path
from data.loader import DataLoader, KlineSchema
from data.sources.parquet_source import ParquetSource
from data.universe.sectors import SECTOR_MAP_OVERSEAS

MARKET_DATA = Path("../../market_data")
kline_source = ParquetSource(MARKET_DATA / "kline/overseas_daily_full")
# TODO: KlineSchema 适配海外列名（FutContrID, TradeDate, SettlePrice...）

# %% [markdown]
# ## 2. 信号 / 回测 / 分析（同国内流程）

# %%
# 参考 国内期货趋势策略全流程.ipynb，替换数据源和 SECTOR_MAP_OVERSEAS
